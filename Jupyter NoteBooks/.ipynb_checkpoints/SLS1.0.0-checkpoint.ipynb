# %% [markdown]
# # Seed Spacing Intial Apporach
#
# The goal of this project is to figure out the distance between 2 seeds from a video feed provided with gps data

# %%
from utils.filehandling import LoadFilesWithExtensions
import pandas as pd
import os
import torch
import torchvision
import numpy as np
from .. import seed_distance_estimator


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_23714/313976215.py in <module>
# ----> 1 from utils.filehandling import LoadFilesWithExtensions
#       2 import pandas as pd
#       3 import os
#       4 import torch
#       5 import torchvision
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Loading Trained CNN Model, CSV File Containing GPS information and the path of video file

model_path = "CNNModels/retina_fp_50.pth"
retina_net = RetinaNetSeedPredictor("Retina Net 18", model_path, device)
video_file = "../Data/exp3/2-34/Video.avi"
gps_file = "../Data/exp3/2-34/GpsData.csv"
csv_data_frame = pd.read_csv(csv_file)
csv_data_frame.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23714/2064901907.py in <module>
#       2
#       3 model_path = "CNNModels/retina_fp_50.pth"
# ----> 4 retina_net = RetinaNetSeedPredictor("Retina Net 18", model_path, device)
#       5 video_file = "../Data/exp3/2-34/Video.avi"
#       6 gps_file = "../Data/exp3/2-34/GpsData.csv"
#
# NameError: name 'RetinaNetSeedPredictor' is not defined

# %%
import cv2 as cv

spc.cap.get(cv.CAP_PROP_FRAME_COUNT)
# Out:
# 0.0

# %%
spc = SeedSpacingCalculator(video_file_path=video_file, csv_data_frame=csv_data_frame, Model=retina_net, x_factor=0.13335)
spc.seek(0.2)
#spc.seek_frame(830)
distances = spc.getSpacing(max_count=None, threshold=0.25, reset=False)
# Out:
# 0

# %%
test1 = distance_struct()
test1.cum_distance = -1
m1 = np.linspace(-1, 5, 7)
print(m1)
m1[test1.filter_out_seen_seeds(m1, 0.5, 2)]
# Out:
# [-1.  0.  1.  2.  3.  4.  5.]
# array([2., 3., 4., 5.])

# %%
# Histograms

import matplotlib.pyplot as plot 
# %matplotlib inline

n_bins = 300
for i in range(4):
    plot.hist([seed_attribute.distance for seed_attribute in distances[i].seed_attributes], bins=n_bins)
    plot.title('Camera {}'.format(i+3))
    plot.xlabel("Distance(M)")
    plot.ylabel("Number (N)")
    plot.savefig("Hist_{}.png".format(i))
    plot.show()

# %%
import utm
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

lat_col, long_col = 'Amplitude - Lat', 'Amplitude - Long' 
lat_long = list(zip(csv_data_frame[lat_col][spc.seeked::4], -csv_data_frame[long_col][spc.seeked::4]))
utm_cords = [utm.from_latlon(lat, long) for lat, long in lat_long]

# %%
e, n, zones, letter = zip(*utm_cords)
le, de, ln, dn = min(e), max(e) - min(e), min(n), max(n) - min(n)
limiter = de
if(dn > de):
    limiter = dn
e_limits = (le, le + limiter)
n_limits = (ln, ln + limiter)
fig, ax = plt.subplots()
ax.plot(e, n)
Easting, Northing, _, _ = utm.from_latlon(39.4239257, -96.5139257)

ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax.xaxis.set_major_formatter(FormatStrFormatter('%.3f'))
ax.set_xlabel("Northing (m)")
ax.set_ylabel("Easting (m)")
ax.locator_params(axis='x', nbins=4)

# %%
plt.plot(csv_data_frame[lat_col][323::4], -csv_data_frame[long_col][323::4])

# %%
a = list(range(10))
a[::2]
# Out:
# [0, 2, 4, 6, 8]

# %%
import Proj
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_20357/594223442.py in <module>
# ----> 1 import Proj
#
# ModuleNotFoundError: No module named 'Proj'

# %%
# !pip install pyproj
# Out:
# Collecting pyproj
#   Downloading pyproj-3.2.1-cp38-cp38-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: certifi in /home/harsha/Desktop/YoloR/seed_spacing/lib/python3.8/site-packages (from pyproj) (2021.5.30)
# Installing collected packages: pyproj
# Successfully installed pyproj-3.2.1
# WARNING: You are using pip version 21.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/harsha/Desktop/YoloR/seed_spacing/bin/python -m pip install --upgrade pip' command.

# %%
utm.from_latlon(39.4239257, -96.5139257)
# Out:
# (713996.1763280682, 4366771.152407691, 14, 'S')

# %%
plt.plot(e, n)
plt.plot()

# %%
gpsF = pd.read_csv("GpsData/westmore_land.csv")

# %%
gpsF
# Out:
#      Name          Lat-1         Long-1          Lat-4         Long-4  \
# 0   2_5_A   39.4234035°N  96.5137149°W    39.4234093°N  96.5136917°W
# 1   2_5_B   39.4234505°N   96.5137129°W   39.4234490°N  96.5136901°W
# 2   2_4_A   39.4238412°N  96.5136970°W    39.4239160°N  96.5136707°W
# 3   2_4_B   39.4238900°N  96.5136947°W    39.4239661°N  96.5136695°W
# 4   2_6_A   39.4232452°N  96.5139429°W    39.4232747°N  96.5139155°W
# 5   2_6_B   39.4232928°N  96.5139407°W    39.4233224°N   96.5139131°W
# 6   2_7_A   39.4238240°N   96.5139192°W   39.4238835°N  96.5138900°W
# 7   2_7_B   39.4238758°N  96.5139172°W    39.4239312°N  96.5138888°W
# 8   1_4_A   39.4239257°N  96.5139257°W    39.4239179°N  96.5139520°W
# 9   1_4_B   39.4238780°N  96.5139277°W    39.4238680°N  96.5139541°W
# 10  1_5_A   39.4233224°N  96.5139495°W    39.4233219°N  96.5139763°W
# 11  1_5_B   39.4232752°N  96.5139517°W    39.4232735°N  96.5139782°W
# 12  1_6_A   39.4232879°N  96.5141552°W    39.4232835°N  96.5141294°W
# 13  1_6_B   39.4233360°N  96.5141532°W    39.4233311°N  96.5141270°W
# 14  1_7_A   39.4237857°N  96.5141343°W    39.4237730°N  96.5141089°W
# 15  1_7_B   39.4238342°N  96.5141329°W    39.4238227°N  96.5141070°W
# 16  3_4_A   39.4233603°N  96.5141619°W    39.4233665°N  96.5141867°W
# 17  3_4_B   39.4233131°N  96.5141637°W    39.4233192°N  96.5141899°W
# 18  3_5_A   39.4226496°N  96.5141907°W    39.4226381°N  96.5142176°W
